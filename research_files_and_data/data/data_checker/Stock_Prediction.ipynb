# %%
import pandas as pd

# %%
data_dir = '/content/drive/MyDrive/stock_project_train_data'

# %%
row_tickers = pd.read_csv(f'{data_dir}/tickers/AAPL.csv')
row_tickers.head()
# Out:
#         Price               Close                High                Low  \
# 0      Ticker                AAPL                AAPL               AAPL
# 1        Date                 NaN                 NaN                NaN
# 2  2019-03-04    42.0208854675293   42.47490550245711  41.57164198093791
# 3  2019-03-05  41.944419860839844  42.056730740309895  41.70784943778627
# 4  2019-03-06   41.70307922363281   41.93486948700485  41.56448272054905
#
#                 Open     Volume
# 0               AAPL       AAPL
# 1                NaN        NaN
# 2  41.98265120351724  109744800
# 3  42.04239380186186   78949600
# 4  41.73892157519718   83241600

# %%
proccesed_data = pd.read_csv(f'{data_dir}/processed/AAPL.csv')
proccesed_data.head()
# Out:
#          Date     Volume      SMA_5     EMA_12     EMA_26     RSI_14  \
# 0  2019-03-29   94256000  45.051844  44.760960  43.924135  62.065972
# 1  2019-04-01  111448000  45.171323  44.905191  44.055567  64.169717
# 2  2019-04-02   91062800  45.516859  45.129434  44.226471  68.255603
# 3  2019-04-03   93087200  45.845666  45.368074  44.408258  70.017204
# 4  2019-04-04   76457200  46.178777  45.582500  44.582597  70.468383
#
#        MACD   BB_upper   BB_lower  Momentum_10  ...  EMA_12_XLK  EMA_26_XLK  \
# 0  0.836825  47.090855  40.707360     0.020578  ...   68.932282   68.247401
# 1  0.849624  47.242706  40.923267     0.017126  ...   69.210108   68.431901
# 2  0.902963  47.451870  41.155938     0.040154  ...   69.482918   68.620900
# 3  0.959816  47.621008  41.484552     0.038212  ...   69.802264   68.838512
# 4  0.999902  47.619167  42.040538     0.003076  ...   70.026052   69.017651
#
#    RSI_14_XLK  MACD_XLK  BB_upper_XLK  BB_lower_XLK  Momentum_10_XLK  \
# ...

# %%
news_raw = pd.read_csv(f'{data_dir}/news_raw/AAPL_20190302_20240302.csv')
news_raw.head()
# Out:
#   ticker                                           news_url   source_name  \
# 0   AAPL  https://www.forbes.com/sites/janetwburns/2020/...        Forbes
# 1   AAPL  https://www.cnbc.com/2020/05/31/apple-ceo-tim-...          CNBC
# 2   AAPL  https://www.cnbc.com/2020/05/31/amazon-target-...          CNBC
# 3   AAPL  https://www.marketwatch.com/story/apple-closes...  Market Watch
# 4   AAPL  https://www.cnet.com/news/apple-closes-apple-s...          CNET
#
#                                                title  \
# 0  Uber Goes Hourly, Amazon Cites Black Lives, Ap...
# 1  Read the email Tim Cook sent to Apple employee...
# 2  Amazon, Target and Apple scale back business i...
# 3  Apple closes many U.S. stores amid protests, l...
# 4  Apple closes Apple stores across US amid wides...
#
#                                                 text  \
# 0  As tens of thousands across the country protes...
# 1  In a memo to employees on Sunday, Apple CEO Co...
# ...

# %%
news_scored = pd.read_csv(f'{data_dir}/news_scored/AAPL_20190302_20240302.csv')
news_scored.head()
# Out:
#   ticker                                           news_url   source_name  \
# 0   AAPL  https://www.forbes.com/sites/janetwburns/2020/...        Forbes
# 1   AAPL  https://www.cnbc.com/2020/05/31/apple-ceo-tim-...          CNBC
# 2   AAPL  https://www.cnbc.com/2020/05/31/amazon-target-...          CNBC
# 3   AAPL  https://www.marketwatch.com/story/apple-closes...  Market Watch
# 4   AAPL  https://www.cnet.com/news/apple-closes-apple-s...          CNET
#
#                                                title  \
# 0  Uber Goes Hourly, Amazon Cites Black Lives, Ap...
# 1  Read the email Tim Cook sent to Apple employee...
# 2  Amazon, Target and Apple scale back business i...
# 3  Apple closes many U.S. stores amid protests, l...
# 4  Apple closes Apple stores across US amid wides...
#
#                                                 text  \
# 0  As tens of thousands across the country protes...
# 1  In a memo to employees on Sunday, Apple CEO Co...
# ...

# %%
final_data =  pd.read_csv(f'/content/drive/MyDrive/train_data/TSLA.csv')
final_data.dropna(inplace=True)
final_data.head()
# Out:
#           Date     Volume      SMA_5     EMA_12     EMA_26     RSI_14  \
# 12  2019-03-04  118791000  19.004667  18.720075  18.901998  51.147212
# 13  2019-03-05  355602000  16.177333  16.739765  17.377374  42.775693
# 14  2019-03-06  195966000  12.412133  13.158077  14.414274  13.868835
# 15  2019-03-07  213016500  15.105600  14.890738  14.678979  71.344318
# 16  2019-03-09   80311500  14.693334  14.794450  15.037016  42.347166
#
#         MACD   BB_upper   BB_lower  Momentum_10  ...  Momentum_10_XLK  \
# 12 -0.181923  19.820349  17.291917     1.214001  ...         2.629997
# 13 -0.637610  19.263283  15.391783    -1.215332  ...         1.019997
# 14 -1.256197  17.569639  10.960828    -2.137335  ...        -4.750000
# 15  0.211759  15.650278  13.628322     0.564667  ...         2.279999
# 16 -0.242566  15.975132  13.896601    -0.121333  ...        -0.910004
#
#     Volatility_10d_XLK  DailySent  HasSent  Return_5d  y_5d  Sent_5d_Avg  \
# ...
